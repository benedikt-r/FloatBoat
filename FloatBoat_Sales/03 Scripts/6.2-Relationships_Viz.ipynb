# %% [markdown]
# 1. Import Libraries
# 2. Import Data Set
# 3. Heat Map
# 4. Scatterplot
# 5. Pair Plot
# 6. Categorical plot
# 7. Questions Revisited
# 8. Hypothesis

# %%
# 1. Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# 2. Import Data Set

# %%
path = r'C:\Users\RUD\Desktop\A6_Boat_Sales'

# %%
df_boat = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'boat_data_wrangled.csv'), index_col = False)

# %%
df_boat.columns
# Out:
# Index(['Unnamed: 0', 'Boat Type', 'Manufacturer', 'Type', 'Year Built',
#        'Length', 'Width', 'Material', 'Location',
#        'Number of views last 7 days', 'Price in EUR'],
#       dtype='object')

# %%
df_boat.head()
# Out:
#    Unnamed: 0            Boat Type            Manufacturer  \
# 0           1  Center console boat       Terhi power boats
# 1           4         Fishing Boat      Linder power boats
# 2          10         Fishing Boat       Terhi power boats
# 3          12           Sport Boat  GS Nautica power boats
# 4          13             Runabout      Kimple power boats
#
#                   Type  Year Built  Length  Width       Material     Location  \
# 0  new boat from stock        2020    4.00   1.50  Thermoplastic      Germany
# 1  new boat from stock        2019    3.55   1.46      Aluminium      Germany
# 2   Used boat,Electric        1987    4.35   1.75            GRP  Switzerland
# 3            Used boat        2004    4.70   2.00            GRP        Italy
# 4  new boat from stock        2020    4.40   1.65      Aluminium  Switzerland
#
#    Number of views last 7 days  Price in EUR
# 0                           75          3490
# 1                           58          3399
# 2                          239          3535
# 3                           69          3500
# 4                          113          4646

# %%
df_boat.describe()
# Out:
#         Unnamed: 0   Year Built       Length        Width  \
# count  6607.000000  6607.000000  6607.000000  6607.000000
# mean   4885.529590  2006.764038    11.228538     3.476063
# std    2829.994106    12.658449     5.177174     1.120912
# min       1.000000  1901.000000     2.320000     0.860000
# 25%    2412.500000  2000.000000     7.470000     2.550000
# 50%    4874.000000  2008.000000    10.000000     3.300000
# 75%    7329.500000  2018.000000    13.720000     4.200000
# max    9887.000000  2021.000000    56.000000    16.000000
#
#        Number of views last 7 days  Price in EUR
# count                  6607.000000  6.607000e+03
# mean                    162.011200  2.772538e+05
# std                     170.771177  7.445500e+05
# min                      13.000000  3.399000e+03
# 25%                      73.000000  4.499450e+04
# 50%                     113.000000  9.500000e+04
# 75%                     187.000000  2.490000e+05
# max                    3263.000000  2.350000e+07

# %%
sub = df_boat[[ 'Year Built',
       'Length', 'Width',
       'Number of views last 7 days', 'Price in EUR']]

# %%
sub
# Out:
#       Year Built  Length  Width  Number of views last 7 days  Price in EUR
# 0           2020    4.00   1.50                           75          3490
# 1           2019    3.55   1.46                           58          3399
# 2           1987    4.35   1.75                          239          3535
# 3           2004    4.70   2.00                           69          3500
# 4           2020    4.40   1.65                          113          4646
# ...          ...     ...    ...                          ...           ...
# 6602        1974    7.20   2.70                         1299          5050
# 6603        1980    6.00   2.10                         1917          5048
# 6604        1984    6.00   1.62                          288          4999
# 6605        2020    4.40   1.80                          354          4499
# 6606        2019    3.60   1.60                          194          3817
#
# [6607 rows x 5 columns]

# %%
# 3. Heat Map

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %%
# The highest correlation is between Length and Width which is not a big surprise because there are bigger and smaller boats.
# The next best correlation (in red is) between Length and Price and then Width and Price: Big boats are usually more expensive
# than smaller ones. I considered expansive boats to get more views (one of my research questions)
# Other correlations seem to be unlikely

# %%
# 4. Scatterplot

# %%
sub
# Out:
#       Year Built  Length  Width  Number of views last 7 days  Price in EUR
# 0           2020    4.00   1.50                           75          3490
# 1           2019    3.55   1.46                           58          3399
# 2           1987    4.35   1.75                          239          3535
# 3           2004    4.70   2.00                           69          3500
# 4           2020    4.40   1.65                          113          4646
# ...          ...     ...    ...                          ...           ...
# 6602        1974    7.20   2.70                         1299          5050
# 6603        1980    6.00   2.10                         1917          5048
# 6604        1984    6.00   1.62                          288          4999
# 6605        2020    4.40   1.80                          354          4499
# 6606        2019    3.60   1.60                          194          3817
#
# [6607 rows x 5 columns]

# %%
sns.lmplot(x = 'Length', y = 'Price in EUR', data = sub)

# %%
# THe correlation is visable - but there are a few outliners which should be analysed in detail:
# maybe they are older or used boats

# %%
# 5. Pair Plot

# %%
# Create a pair plot 

df_boat = sns.pairplot(df_boat)
# Out:
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# I'm interested in the views variable because this is a vital metric for an E-Commerce business and which boat types
# are popular. This could be a starting point for a segmented marketing campaign for example.

# %%
# 6.Categorical plot

# %%
df_boat = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'boat_data_wrangled.csv'), index_col = False)

# %%
sns.histplot(df_boat['Number of views last 7 days'], bins = 70, kde = True)
# Out:
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Number of views last 7 days', ylabel='Count'>

# %%
df_boat.loc[df_boat['Number of views last 7 days'] < 100, 'Visibility'] = 'Low Visibility'
df_boat.loc[(df_boat['Number of views last 7 days'] >= 100) & (df_boat['Number of views last 7 days'] < 300), 'Visibility'] = 'Middle Visibility'
df_boat.loc[df_boat['Number of views last 7 days'] >= 300, 'Visibility'] = 'High Visibility'

# %%
df_boat['Visibility'].value_counts(dropna = False)
# Out:
# Visibility
# Middle Visibility    3098
# Low Visibility       2772
# High Visibility       737
# Name: count, dtype: int64

# %%
df_boat
# Out:
#       Unnamed: 0                                Boat Type  \
# 0              1                      Center console boat
# 1              4                             Fishing Boat
# 2             10                             Fishing Boat
# 3             12                               Sport Boat
# 4             13                                 Runabout
# ...          ...                                      ...
# 6602        9877                               Cabin Boat
# 6603        9878  Sport Boat,Wakeboard/Wakesurf,Water ski
# 6604        9882                             Fishing Boat
# 6605        9885                               Sport Boat
# 6606        9887                             Fishing Boat
#
#                    Manufacturer                          Type  Year Built  \
# 0             Terhi power boats           new boat from stock        2020
# 1            Linder power boats           new boat from stock        2019
# 2             Terhi power boats            Used boat,Electric        1987
# 3        GS Nautica power boats                     Used boat        2004
# 4            Kimple power boats           new boat from stock        2020
# ...                         ...                           ...         ...
# 6602       Princess power boats                     Used boat        1974
# 6603  Tullio Abbate power boats            Used boat,Unleaded        1980
# 6604      Staempfli power boats            Used boat,Unleaded        1984
# 6605      BlueCraft power boats  new boat from stock,Unleaded        2020
# 6606        DarekCo power boats           new boat from stock        2019
#
#       Length  Width       Material     Location  Number of views last 7 days  \
# 0       4.00   1.50  Thermoplastic      Germany                           75
# 1       3.55   1.46      Aluminium      Germany                           58
# 2       4.35   1.75            GRP  Switzerland                          239
# 3       4.70   2.00            GRP        Italy                           69
# 4       4.40   1.65      Aluminium  Switzerland                          113
# ...      ...    ...            ...          ...                          ...
# 6602    7.20   2.70            GRP  Switzerland                         1299
# 6603    6.00   2.10            GRP  Switzerland                         1917
# 6604    6.00   1.62        Plastic  Switzerland                          288
# 6605    4.40   1.80            GRP      Germany                          354
# 6606    3.60   1.60            GRP  Switzerland                          194
#
#       Price in EUR         Visibility
# 0             3490     Low Visibility
# 1             3399     Low Visibility
# 2             3535  Middle Visibility
# 3             3500     Low Visibility
# 4             4646  Middle Visibility
# ...            ...                ...
# 6602          5050    High Visibility
# 6603          5048    High Visibility
# 6604          4999  Middle Visibility
# 6605          4499    High Visibility
# 6606          3817  Middle Visibility
#
# [6607 rows x 12 columns]

# %%
df_boat.columns
# Out:
# Index(['Unnamed: 0', 'Boat Type', 'Manufacturer', 'Type', 'Year Built',
#        'Length', 'Width', 'Material', 'Location',
#        'Number of views last 7 days', 'Price in EUR', 'Visibility'],
#       dtype='object')

# %%
# Create a categorical plot in seaborn using the Visability categories created above

sns.set(style="ticks")
g = sns.catplot(x="Year Built", y="Number of views last 7 days", hue="Visibility", data=df_boat)
# Out:
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\RUD\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Visability increases for newer boats - older boats don't have that much Visibility

# %%
#7 . Questions Revisited

# %% [markdown]
# Which boats were most viewed? Newer boats as seen above
#
# Is there a relationship between views and price? The heat map tells No.

# %%
# 8. Hypothesis / further

# %% [markdown]
# If a boat is newer than it will get more views.
# If a boat is smaller in length it will be cheaper in price.

# %%
df_boat.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'boat_data_relation.csv'))
